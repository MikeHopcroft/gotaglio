# %% [markdown]
# # Calculator Sample

# %% [markdown]
# This is a simple pipeline that demonstrates using an LLM to calculate the value of arithmetic expressions.
# Each test cases processes a single expression entered by the user. See the [menu](../menu/menu.ipynb) notebook
# for an example where each test case has multiple turns.
#
# Define your pipeline. In this case we're using the `calc` sample defined in [calc.py](./calc.py).

# %%
from calc import calc_pipeline_spec

# %% [markdown]
# Define your test cases. Note that the second case uses a textual description of the expression
# and that the third case specifies base 16 or hexidecimal for the input.

# %%
cases = [
  {
    "uuid": "6f31c4df-bba6-42cd-a3ae-24f31d5503fa",
    "keywords": ["numbers"],
    "user": "1+1",
    "base": 10,
    "answer": 2
  },
  {
    "uuid": "ceb61568-73c9-4b5e-812f-0fa2df1464f1",
    "keywords": ["text"],
    "user": "one hundred two divided by two",
    "base": 10,
    "answer": 51
  },
  {
    "uuid": "178f2c37-557f-4d89-b48d-4f07e828e6ff",
    "keywords": ["hexidecimal"],
    "user": "ff + a",
    "base": 16,
    "answer": 265
  }
]

# %% [markdown]
# Instantiate the Gotaglio object that runs the pipeline.

# %%
from gotaglio.gotag import Gotaglio

gt = Gotaglio([calc_pipeline_spec])

# %% [markdown]
# Run the calculator pipeline and store the runlog in `result`. The format the results as an annotated transcription a conversation between the
# `system`, `assistant`, and `user`. Note that this example uses the built-in `perfect` model mock that always provides the correct answer.
# Once you have set up credentials, you can use a more interesting model like `gpt4o`.

# %%
result = gt.run(
  "calc",
  cases,
  {
    "prepare.template": "data/template.txt",
    "infer.model.name": "perfect"
  },
  save=True
)
gt.format(result)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             Summary for 0b32d1c8-e7b7-48c6-865a-7ef6acffd8e2
# ┏━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃  id ┃ status   ┃ cost ┃ keywords    ┃ user                           ┃
# ┡━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 6f3 │ COMPLETE │ 0.00 │ numbers     │ 1+1                            │
# │ ceb │ COMPLETE │ 0.00 │ text        │ one hundred two divided by two │
# │ 178 │ COMPLETE │ 0.00 │ hexidecimal │ ff + a                         │
# └─────┴──────────┴──────┴─────────────┴────────────────────────────────┘
#
# Total: 3
# Complete: 3/3 (100.00%)
# Error: 0/3 (0.00%)
# Passed: 3/3 (100.00%)
# Failed: 0/3 (0.00%)
#
#
# Results written to logs\0b32d1c8-e7b7-48c6-865a-7ef6acffd8e2.json
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ## Run: 0b32d1c8-e7b7-48c6-865a-7ef6acffd8e2
# **Configuration deltas:**
#
# * prepare.template: PROMPT => data/template.txt
# * infer.model.name: PROMPT => perfect
# ## Case: 6f3 - PASSED
# **Keywords:** numbers
#
#
# **system:**
# You are a desktop calculator that computes the value of mathematical expressions.
# The input is base 10.
# Your output should be just a base 10 numerical result.
#
# **user:** _1+1_
#
# **assistant:**
# 2.0
#
#
# ## Case: ceb - PASSED
# **Keywords:** text
#
#
# **system:**
# You are a desktop calculator that computes the value of mathematical expressions.
# The input is base 10.
# Your output should be just a base 10 numerical result.
#
# **user:** _one hundred two divided by two_
#
# **assistant:**
# 51.0
#
#
# ## Case: 178 - PASSED
# **Keywords:** hexidecimal
#
#
# **system:**
# You are a desktop calculator that computes the value of mathematical expressions.
# The input is base 16.
# Your output should be just a base 10 numerical result.
#
# **user:** _ff + a_
#
# **assistant:**
# 265.0

# %% [markdown]
# We can rerun this example with a different model, this time the `flakey` mock, which alternately returns the correct answer, returns "hello world", and raises an exception. The mock models are good for debugging new pipelines locally, before connecting to a real model.

# %%
result2 = gt.rerun(
  result,
  {
    "infer.model.name": "flakey"
  },
  save=True
)
gt.format(result2)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             Summary for adb03620-16a6-4eca-8917-848de8320133
# ┏━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃  id ┃ status   ┃ cost ┃ keywords    ┃ user                           ┃
# ┡━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 6f3 │ COMPLETE │ 0.00 │ numbers     │ 1+1                            │
# │ ceb │ ERROR    │      │ text        │ one hundred two divided by two │
# │ 178 │ ERROR    │      │ hexidecimal │ ff + a                         │
# └─────┴──────────┴──────┴─────────────┴────────────────────────────────┘
#
# Total: 3
# Complete: 1/3 (33.33%)
# Error: 2/3 (66.67%)
# Passed: 1/3 (33.33%)
# Failed: 0/3 (0.00%)
#
#
# Results written to logs\adb03620-16a6-4eca-8917-848de8320133.json
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ## Run: adb03620-16a6-4eca-8917-848de8320133
# **Configuration deltas:**
#
# * prepare.template: PROMPT => data/template.txt
# * infer.model.name: PROMPT => flakey
# ## Case: 6f3 - PASSED
# **Keywords:** numbers
#
#
# **system:**
# You are a desktop calculator that computes the value of mathematical expressions.
# The input is base 10.
# Your output should be just a base 10 numerical result.
#
# **user:** _1+1_
#
# **assistant:**
# 2.0
#
#
# ## Case: ceb - FAILED
# **Keywords:** text
#
#
# ### Turn 1: **ERROR**
# Error: Context: Extracting numerical answer from LLM response.
# Error: could not convert string to float: 'hello world'
#
# ~~~
# Traceback: Traceback (most recent call last):
#   File "C:\git\llm-tools\gotaglio\gotaglio\dag.py", line 206, in run_dag
#     await run_dag_helper(dag_object, stages, timing, context, 0, False)
#   File "C:\git\llm-tools\gotaglio\gotaglio\dag.py", line 388, in run_dag_helper
#     name = task.result()
#            ^^^^^^^^^^^^^
#   File "C:\Users\mhop\AppData\Local\Programs\Python\Python312\Lib\asyncio\futures.py", line 202, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "C:\Users\mhop\AppData\Local\Programs\Python\Python312\Lib\asyncio\tasks.py", line 314, in
# __step_run_and_handle_result
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "C:\git\llm-tools\gotaglio\gotaglio\dag.py", line 166, in run_task
#     raise e
#   File "C:\git\llm-tools\gotaglio\gotaglio\dag.py", line 156, in run_task
#     result = await dag.function(context, turn_index, isolated)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\git\llm-tools\gotaglio\samples\calc\calc.py", line 144, in extract
#     return float(context["stages"]["infer"])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: 'hello world'
#
# Time: 2025-10-12 20:48:44.619708+00:00
# ~~~
# ## Case: 178 - FAILED
# **Keywords:** hexidecimal
#
#
# ### Turn 1: **ERROR**
# Error: Error: Flakey model failed
#
# ~~~
# Traceback: Traceback (most recent call last):
#   File "C:\git\llm-tools\gotaglio\gotaglio\dag.py", line 206, in run_dag
#     await run_dag_helper(dag_object, stages, timing, context, 0, False)
#   File "C:\git\llm-tools\gotaglio\gotaglio\dag.py", line 388, in run_dag_helper
#     name = task.result()
#            ^^^^^^^^^^^^^
#   File "C:\Users\mhop\AppData\Local\Programs\Python\Python312\Lib\asyncio\futures.py", line 202, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "C:\Users\mhop\AppData\Local\Programs\Python\Python312\Lib\asyncio\tasks.py", line 314, in
# __step_run_and_handle_result
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "C:\git\llm-tools\gotaglio\gotaglio\dag.py", line 166, in run_task
#     raise e
#   File "C:\git\llm-tools\gotaglio\gotaglio\dag.py", line 156, in run_task
#     result = await dag.function(context, turn_index, isolated)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\git\llm-tools\gotaglio\samples\calc\calc.py", line 137, in infer
#     return await model.infer(context["stages"]["prepare"], context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\git\llm-tools\gotaglio\gotaglio\mocks.py", line 53, in infer
#     raise Exception("Flakey model failed")
# Exception: Flakey model failed
#
# Time: 2025-10-12 20:48:44.621719+00:00
# ~~~

# %% [markdown]
# Note that we can use the term `"latest"` to refer to the most recently generated runlog.
# We could also pass the first few characters of a run's UUID or we could pass the result
# object (e.g. `result` or `result2`) directly.

# %%
gt.summarize("latest")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             Summary for adb03620-16a6-4eca-8917-848de8320133
# ┏━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃  id ┃ status   ┃ cost ┃ keywords    ┃ user                           ┃
# ┡━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 6f3 │ COMPLETE │ 0.00 │ numbers     │ 1+1                            │
# │ ceb │ ERROR    │      │ text        │ one hundred two divided by two │
# │ 178 │ ERROR    │      │ hexidecimal │ ff + a                         │
# └─────┴──────────┴──────┴─────────────┴────────────────────────────────┘
#
# Total: 3
# Complete: 1/3 (33.33%)
# Error: 2/3 (66.67%)
# Passed: 1/3 (33.33%)
# Failed: 0/3 (0.00%)

# %% [markdown]
# Gotaglio allows us to compare the results of two runs.

# %%
gt.compare(result, result2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 gt.compare(result, result2)
#
# File C:\git\llm-tools\gotaglio\gotaglio\gotag.py:48, in Gotaglio.compare(self, a, b)
#      46 runlog_a = runlog_from_runlog_or_prefix(a)
#      47 runlog_b = runlog_from_runlog_or_prefix(b)
# ---> 48 compare(self._pipeline_specs, runlog_a, runlog_b)
#
# File C:\git\llm-tools\gotaglio\gotaglio\compare.py:69, in compare(pipeline_specs, a, b)
#      67 pass_count_b = 0
#      68 for uuid in both:
# ---> 69     (text_a, order_a) = format_status(pipeline_spec, a_cases[uuid])
#      70     (text_b, order_b) = format_status(pipeline_spec, b_cases[uuid])
#      71     keywords = ", ".join(sorted(a_cases[uuid]["case"].get("keywords", [])))
#
# File C:\git\llm-tools\gotaglio\gotaglio\compare.py:101, in format_status(pipeline_spec, result)
#      99 def format_status(pipeline_spec: PipelineSpec, result: dict[str, Any]):
#     100     if result["succeeded"]:
# --> 101         if pipeline_spec.passed_predicate(result):
#     102             return (Text("passed", style="bold green"), 0)
#     103         else:
#
# TypeError: passed_predicate() missing 1 required positional argument: 'turn_index'
